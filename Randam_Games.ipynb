# %% [markdown]
# <a href="https://colab.research.google.com/github/sajalgoyal007/Games/blob/main/Randam_Games.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
num = random.randint(1, 100)
print(f"the number is {num}")
tries = 0
while True:
  tries += 1
  guess = int(input("Please guess the number btw 1 - 100:-"))
  if guess == num:
      print(f"You are right and you guessed the number in {tries} tries")
      break
  elif num > guess:
      print("number is greater")
  else:
    print("number is smaller")
# Out:
# the number is 63
# Please guess the number btw 1 - 100:-50
# number is greater
# Please guess the number btw 1 - 100:-70
# number is smaller
# Please guess the number btw 1 - 100:-60
# number is greater
# Please guess the number btw 1 - 100:-65
# number is smaller
# Please guess the number btw 1 - 100:-62
# number is greater
# Please guess the number btw 1 - 100:-63
# You are right and you guessed the number in 6 tries
